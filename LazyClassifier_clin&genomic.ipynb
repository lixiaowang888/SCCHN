# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np


data = pd.read_csv('TCGA101_add.txt',sep='\t')
col = data.columns.values.tolist()

X = np.array(data[col[1:215]])
y= data['Recurrence']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =8)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 30.46it/s]
# [10:51:46] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearDiscriminantAnalysis         0.76               0.76     0.76      0.78
# BernoulliNB                        0.71               0.63     0.63      0.73
# XGBClassifier                      0.86               0.62     0.62      0.82
# DecisionTreeClassifier             0.67               0.60     0.60      0.70
# AdaBoostClassifier                 0.81               0.60     0.60      0.78
# LGBMClassifier                     0.81               0.60     0.60      0.78
# GaussianNB                         0.76               0.57     0.57      0.75
# DummyClassifier                    0.76               0.57     0.57      0.75
# NearestCentroid                    0.57               0.54     0.54      0.62
# Perceptron                         0.52               0.51     0.51      0.57
# ExtraTreeClassifier                0.67               0.51     0.51      0.68
# KNeighborsClassifier               0.81               0.50     0.50      0.72
# LabelPropagation                   0.81               0.50     0.50      0.72
# LabelSpreading                     0.81               0.50     0.50      0.72
# CalibratedClassifierCV             0.81               0.50     0.50      0.72
# ExtraTreesClassifier               0.81               0.50     0.50      0.72
# SVC                                0.81               0.50     0.50      0.72
# RandomForestClassifier             0.81               0.50     0.50      0.72
# RidgeClassifierCV                  0.62               0.48     0.48      0.65
# BaggingClassifier                  0.76               0.47     0.47      0.70
# PassiveAggressiveClassifier        0.57               0.45     0.45      0.61
# RidgeClassifier                    0.57               0.45     0.45      0.61
# LinearSVC                          0.57               0.45     0.45      0.61
# QuadraticDiscriminantAnalysis      0.62               0.38     0.38      0.62
# SGDClassifier                      0.57               0.35     0.35      0.59
# LogisticRegression                 0.57               0.35     0.35      0.59
#
#                                Time Taken
# Model
# LinearDiscriminantAnalysis           0.02
# BernoulliNB                          0.01
# XGBClassifier                        0.08
# DecisionTreeClassifier               0.02
# AdaBoostClassifier                   0.12
# LGBMClassifier                       0.06
# GaussianNB                           0.02
# DummyClassifier                      0.02
# NearestCentroid                      0.01
# Perceptron                           0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.02
# LabelPropagation                     0.02
# LabelSpreading                       0.02
# CalibratedClassifierCV               0.04
# ExtraTreesClassifier                 0.13
# SVC                                  0.01
# RandomForestClassifier               0.14
# RidgeClassifierCV                    0.01
# BaggingClassifier                    0.05
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.02
# LinearSVC                            0.02
# QuadraticDiscriminantAnalysis        0.02
# SGDClassifier                        0.01
# LogisticRegression                   0.03
