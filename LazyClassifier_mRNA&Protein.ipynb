# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

data = pd.read_csv('mRNA_Protein33.txt',sep='\t')
col = data.columns.values.tolist()

X = np.array(data[col[1:16]])
y= data['Recurrence']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.3,random_state =4)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 45.70it/s]
# [10:52:38] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelSpreading                     1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# CalibratedClassifierCV             1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# NuSVC                              1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# LabelPropagation                   1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        0.90               0.94     0.94      0.91
# NearestCentroid                    0.90               0.94     0.94      0.91
# LogisticRegression                 0.90               0.94     0.94      0.91
# RidgeClassifierCV                  0.90               0.94     0.94      0.91
# KNeighborsClassifier               0.90               0.94     0.94      0.91
# ExtraTreesClassifier               0.90               0.94     0.94      0.91
# DummyClassifier                    0.90               0.94     0.94      0.91
# DecisionTreeClassifier             0.90               0.94     0.94      0.91
# BernoulliNB                        0.90               0.94     0.94      0.91
# LinearDiscriminantAnalysis         0.80               0.89     0.89      0.84
# SGDClassifier                      0.80               0.89     0.89      0.84
# Perceptron                         0.80               0.89     0.89      0.84
# RidgeClassifier                    0.80               0.89     0.89      0.84
# LinearSVC                          0.80               0.89     0.89      0.84
# LGBMClassifier                     0.90               0.50     0.50      0.85
# QuadraticDiscriminantAnalysis      0.90               0.50     0.50      0.85
# ExtraTreeClassifier                0.70               0.39     0.39      0.74
# AdaBoostClassifier                 0.70               0.39     0.39      0.74
#
#                                Time Taken
# Model
# LabelSpreading                       0.01
# BaggingClassifier                    0.02
# RandomForestClassifier               0.12
# CalibratedClassifierCV               0.02
# SVC                                  0.01
# XGBClassifier                        0.05
# NuSVC                                0.01
# GaussianNB                           0.01
# LabelPropagation                     0.01
# PassiveAggressiveClassifier          0.02
# NearestCentroid                      0.01
# LogisticRegression                   0.01
# RidgeClassifierCV                    0.01
# KNeighborsClassifier                 0.01
# ExtraTreesClassifier                 0.09
# DummyClassifier                      0.01
# DecisionTreeClassifier               0.01
# BernoulliNB                          0.01
# LinearDiscriminantAnalysis           0.01
# SGDClassifier                        0.01
# Perceptron                           0.01
# RidgeClassifier                      0.01
# LinearSVC                            0.01
# LGBMClassifier                       0.02
# QuadraticDiscriminantAnalysis        0.01
# ExtraTreeClassifier                  0.01
# AdaBoostClassifier                   0.08
